# %%
import numpy as np 
import sys
from pathlib import Path

repo_root = Path.cwd()
while not (repo_root / "utils").exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent

sys.path.insert(0, str(repo_root))
print(repo_root)
# Out:
# /home/aalexiev/brl/Dexterous-Hand-Retargeting

# %%
#add the root folder in vscode to be able to import the utils



dataset_path = "assets/datasets/retargeted_grasps_test"
grasps = np.load(f"{repo_root}/{dataset_path}/data.npz", allow_pickle=True)

# %%
grasps.files
# Out:
# ['trajectory_id',
#  'capture_name',
#  'frame_id',
#  'phase',
#  'phase_index',
#  'human_mano',
#  'human_shape',
#  'camera_transform',
#  'human_mano_root_translation',
#  'human_mano_root_orientation_wxyz',
#  'retargeted_qpos',
#  'retargeted_mano_root_translation',
#  'retargeted_mano_root_orientation_wxyz',
#  'object_identifier',
#  'object_name',
#  'object_mesh_file',
#  'object_translation',
#  'object_orientation_wxyz']

# %%
grasps['phase']
# Out:
# array(['approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
#        'approach', 'grasp', 'lift', 'approach', 'grasp', 'lift',
# ...
